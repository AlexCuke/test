# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexCuke/test/blob/main/Practice_one_Analitic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
sales = pd.read_csv('/content/drive/My Drive/Colab Notebooks/sales_v2023-07-09.csv', sep=',')
sales.head(10) #first 10 strings
# Out:
#    order_id        date  customer_id         category               region  \
# 0  59570135  2017-10-16          512   Одежда и обувь  Ставропольский край
# 1  16578697  2017-07-18          512   Одежда и обувь  Ставропольский край
# 2  46943601  2017-07-05          512  Бытовая техника  Ставропольский край
# 3  42436035  2017-02-18          512    Спорт и отдых  Ставропольский край
# 4  49798299  2017-09-08          512          Красота  Ставропольский край
# 5  85282012  2017-01-01          512           Аптека  Ставропольский край
# 6  86441447  2017-07-04          513    Спорт и отдых   Московская область
# 7   3468527  2017-05-31          513           Аптека   Московская область
# 8  82105305  2017-03-30          513    Спорт и отдых   Московская область
# 9  23201528  2017-04-22          513           Аптека   Московская область
#
#    sales  quantity  discount
# 0   1301         2      0.00
# 1   3530         4      0.05
# 2   5773         1      0.10
# ...

# %%
sales.info() #info about types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1554192 entries, 0 to 1554191
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   order_id     1554192 non-null  int64
#  1   date         1554192 non-null  object
#  2   customer_id  1554192 non-null  int64
#  3   category     1554192 non-null  object
#  4   region       1554192 non-null  object
#  5   sales        1554192 non-null  int64
#  6   quantity     1554192 non-null  int64
#  7   discount     1554192 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 94.9+ MB

# %%
#df.describe() #statistic

# %%
returns = pd.read_csv('/content/drive/My Drive/Colab Notebooks/returns_v2023-07-09.csv', sep=',')
returns.head(10) #first 10 strings
# Out:
#    order_id  return
# 0  59570135       0
# 1  16578697       0
# 2  46943601       0
# 3  42436035       0
# 4  49798299       0
# 5  85282012       0
# 6  86441447       0
# 7   3468527       0
# 8  82105305       0
# 9  23201528       0

# %%
# %%time

joined = sales.merge(returns, on='order_id')  # Обьединение
joined.head(10)
# Out:
# CPU times: user 801 ms, sys: 158 ms, total: 959 ms
# Wall time: 992 ms
#    order_id        date  customer_id         category               region  \
# 0  59570135  2017-10-16          512   Одежда и обувь  Ставропольский край
# 1  16578697  2017-07-18          512   Одежда и обувь  Ставропольский край
# 2  46943601  2017-07-05          512  Бытовая техника  Ставропольский край
# 3  42436035  2017-02-18          512    Спорт и отдых  Ставропольский край
# 4  49798299  2017-09-08          512          Красота  Ставропольский край
# 5  85282012  2017-01-01          512           Аптека  Ставропольский край
# 6  86441447  2017-07-04          513    Спорт и отдых   Московская область
# 7   3468527  2017-05-31          513           Аптека   Московская область
# 8  82105305  2017-03-30          513    Спорт и отдых   Московская область
# 9  23201528  2017-04-22          513           Аптека   Московская область
#
#    sales  quantity  discount  return
# ...

# %%
sales['category'].unique()
# Out:
# array(['Одежда и обувь', 'Бытовая техника', 'Спорт и отдых', 'Красота',
#        'Аптека', 'Продукты питания', 'Дача и сад', 'Мебель'], dtype=object)

# %%
sales['region'].unique()
# Out:
# array(['Ставропольский край', 'Московская область', 'Хабаровский край',
#        'Красноярский край', 'Амурская область', 'Иркутская область',
#        'Ленинградская область', 'Владимирская область', 'Приморский край',
#        'Краснодарский край', 'Смоленская область'], dtype=object)

# %%
sales.groupby('category').agg({'sales': 'sum'})  # для каждой категории считаем сумму столбца sales # для каждой категории считаем сумму столбца sales
# Out:
#                        sales
# category
# Аптека             253901402
# Бытовая техника   1040194206
# Дача и сад        1095424217
# Красота             74717089
# Мебель             273758727
# Одежда и обувь     678825888
# Продукты питания   891545007
# Спорт и отдых     2084228509
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sales'].plot(kind='hist', bins=20, title='sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['sales'].plot(kind='line', figsize=(8, 4), title='sales')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
pivot = joined.pivot_table(index='category', columns='return', values='sales', aggfunc='count')
pivot
# Out:
# return                 0       1
# category
# Аптека            190354   30561
# Бытовая техника   103481   25704
# Дача и сад        160485   30131
# Красота            55871    9044
# Мебель             22682    7051
# Одежда и обувь    242742   52714
# Продукты питания  222985  165089
# Спорт и отдых     182344   76818

# %%
pivot['returns_share'] = pivot[1] / (pivot[0] + pivot[1])
pivot
# Out:
# return                 0       1  returns_share
# category
# Аптека            190354   30561       0.138338
# Бытовая техника   103481   25704       0.198970
# Дача и сад        160485   30131       0.158072
# Красота            55871    9044       0.139321
# Мебель             22682    7051       0.237144
# Одежда и обувь    242742   52714       0.178416
# Продукты питания  222985  165089       0.425406
# Спорт и отдых     182344   76818       0.296409
